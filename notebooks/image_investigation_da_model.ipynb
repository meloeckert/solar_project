# %%
#load images
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers, optimizers, callbacks
import matplotlib.pyplot as plt 
from PIL import Image
import os
# %matplotlib inline
# Out:
# 2023-08-30 11:33:04.618451: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-30 11:33:04.759758: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-08-30 11:33:04.759781: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-08-30 11:33:04.794991: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-08-30 11:33:05.915931: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-08-30 11:33:05.916058: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-08-30 11:33:05.916071: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Convert files to .jpeg

# %% [markdown]
# ### Convert training-data

# %%
#Code for converting .jpg images to .jpeg
# Define the directory path containing PNG images
dirs = ['clean', 'dirt','damage']

for dir in dirs:
    directory_path = f"raw_data/training-data-exp/{dir}"
    
    # Iterate through the directory and convert images
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.lower().endswith(".jpg"):
                # Load the image
                img_path = os.path.join(root, file)
                img = Image.open(img_path)
                
                # Convert the image to RGB mode
                img = img.convert("RGB")
                
                # Define the new file path with the .jpeg extension
                new_img_path = os.path.splitext(img_path)[0] + ".jpeg"
                
                # Save the image in JPEG format
                img.save(new_img_path, "JPEG")
                
                # Close the image to free resources
                img.close()
    
    print("Image format conversion complete.")
# Out:
# Image format conversion complete.
# Image format conversion complete.
# Image format conversion complete.

# %% [markdown]
# ### Convert test-data

# %%
# Define the directory path containing PNG images
dirs = ['clean', 'dust','bird','electrical', 'physical_damaged','solar']

for dir in dirs:
    directory_path = f"raw_data/test-data/{dir}"
    
    # Iterate through the directory and convert images
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.lower().endswith(".jpg"):
                # Load the image
                img_path = os.path.join(root, file)
                img = Image.open(img_path)
                
                # Convert the image to RGB mode
                img = img.convert("RGB")
                
                # Define the new file path with the .jpeg extension
                new_img_path = os.path.splitext(img_path)[0] + ".jpeg"
                
                # Save the image in JPEG format
                img.save(new_img_path, "JPEG")
                
                # Close the image to free resources
                img.close()
    
    print("Image format conversion complete.")

# %% [markdown]
# ### Delete .jpg files in training-data

# %%
# Define the directory path
# Define the directory path containing PNG images
dirs = ['clean', 'dirt','damage']

for dir in dirs:
    directory_path = f"raw_data/training-data-exp/{dir}"

    # Iterate through the directory and delete JPG files
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.lower().endswith(".jpg"):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted: {file_path}")
    
    print("Deletion complete.")
# Out:
# Deleted: raw_data/training-data-exp/clean/image_18.jpg
# Deletion complete.
# Deletion complete.
# Deletion complete.

# %% [markdown]
# ### Delete .jpg file in test-data

# %%
# Define the directory path
# Define the directory path containing PNG images
dirs = ['clean', 'dust','bird','electrical', 'physical_damaged','solar']

for dir in dirs:
    directory_path = f"raw_data/test-data/{dir}"

    # Iterate through the directory and delete JPG files
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.lower().endswith(".jpg"):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted: {file_path}")
    
    print("Deletion complete.")

# %% [markdown]
# ### Delete Zone.Identifier

# %%
# Define the directory path
dirs = ['clean', 'dirt','damage']

for dir in dirs:
    directory_path = f"raw_data/training-data-exp/{dir}"

    # Iterate through the directory and delete Zone.Identifier files
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            print(file)
            if file.endswith("Zone.Identifier"):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted: {file_path}")

    print("Deletion of Zone.Identifier files complete.")
# Out:
# Cleaan (66).jpeg
# images_17.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_17.jpeg:Zone.Identifier
# Cleaan (7).jpeg
# images_6.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_6.jpeg:Zone.Identifier
# Cleaan (185).jpeg
# Cleaan (123).jpeg
# Cleaan (127).jpeg
# Cleaan (93).jpeg
# images_3.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_3.jpeg:Zone.Identifier
# Cleaan (56).jpeg
# Cleaan (57).jpeg
# images_5.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_5.jpeg:Zone.Identifier
# images_16.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_16.jpeg:Zone.Identifier
# Cleaan (139).jpeg
# Cleaan (31).jpeg
# Cleaan (35).jpeg
# Cleaan (169).jpeg
# Cleaan (61).jpeg
# Cleaan (89).jpeg
# Cleaan (104).jpeg
# Cleaan (137).jpeg
# Cleaan (113).jpeg
# Cleaan (110).jpeg
# Cleaan (68).jpeg
# Cleaan (156).jpeg
# Cleaan (49).jpeg
# Cleaan (17).jpeg
# Cleaan (97).jpeg
# images_10.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_10.jpeg:Zone.Identifier
# Cleaan (44).jpeg
# Cleaan (22).jpeg
# Cleaan (63).jpeg
# Cleaan (128).jpeg
# Cleaan (99).jpeg
# Cleaan (88).jpeg
# images_12.jpeg
# Cleaan (32).jpeg
# images_9.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_9.jpeg:Zone.Identifier
# images_14.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_14.jpeg:Zone.Identifier
# Cleaan (109).jpeg
# Cleaan (2).jpeg
# Cleaan (145).jpeg
# Cleaan (6).jpeg
# Cleaan (79).jpeg
# Cleaan (42).jpeg
# Cleaan (51).jpeg
# Cleaan (1).jpeg
# Cleaan (10).jpeg
# Cleaan (171).jpeg
# Cleaan (12).jpeg
# Cleaan (27).jpeg
# Cleaan (129).jpeg
# Cleaan (18).jpeg
# Cleaan (46).jpeg
# images_21.jpeg
# Cleaan (80).jpeg
# Cleaan (98).jpeg
# Cleaan (72).jpeg
# Cleaan (64).jpeg
# Cleaan (152).jpeg
# Cleaan (13).jpeg
# Cleaan (14).jpeg
# Cleaan (54).jpeg
# Cleaan (87).jpeg
# Cleaan (21).jpeg
# Cleaan (83).jpeg
# images_15.jpeg
# Cleaan (50).jpeg
# Cleaan (178).jpeg
# Cleaan (65).jpeg
# Cleaan (165).jpeg
# Cleaan (111).jpeg
# Cleaan (69).jpeg
# Cleaan (182).jpeg
# images_15.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_15.jpeg:Zone.Identifier
# images_8.jpeg
# image_18.jpeg
# Cleaan (9).jpeg
# images_17.jpeg
# Cleaan (120).jpeg
# Cleaan (135).jpeg
# Cleaan (184).jpeg
# Cleaan (36).jpeg
# Cleaan (150).jpeg
# image_18.jpg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/image_18.jpg:Zone.Identifier
# Cleaan (19).jpeg
# Cleaan (55).jpeg
# Cleaan (195).jpeg
# Cleaan (91).jpeg
# images_19.jpeg
# Cleaan (131).jpeg
# images_7.jpeg
# Cleaan (77).jpeg
# Cleaan (162).jpeg
# Cleaan (8).jpeg
# Cleaan (16).jpeg
# Cleaan (115).jpeg
# Cleaan (151).jpeg
# Cleaan (30).jpeg
# images_11.jpeg
# Cleaan (24).jpeg
# Cleaan (163).jpeg
# Cleaan (133).jpeg
# Cleaan (86).jpeg
# Cleaan (67).jpeg
# Cleaan (172).jpeg
# Cleaan (134).jpeg
# Cleaan (103).jpeg
# Cleaan (1).png
# images_5.jpeg
# Cleaan (158).jpeg
# images_9.jpeg
# Cleaan (148).jpeg
# images_4.jpeg
# Cleaan (196).jpeg
# Cleaan (37).jpeg
# Cleaan (76).jpeg
# Cleaan (179).jpeg
# Cleaan (4).jpeg
# Cleaan (11).jpeg
# Cleaan (125).jpeg
# images_18.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_18.jpeg:Zone.Identifier
# Cleaan (70).jpeg
# Cleaan (33).jpeg
# images_14.jpeg
# Cleaan (191).jpeg
# Cleaan (190).jpeg
# Cleaan (71).jpeg
# Cleaan (59).jpeg
# Cleaan (119).jpeg
# Cleaan (100).jpeg
# Cleaan (40).jpeg
# Cleaan (95).jpeg
# images_10.jpeg
# Cleaan (81).jpeg
# images_3.jpeg
# Cleaan (48).jpeg
# images_8.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_8.jpeg:Zone.Identifier
# Cleaan (90).jpeg
# images_16.jpeg
# Cleaan (52).jpeg
# Cleaan (194).jpeg
# Cleaan (168).jpeg
# images_21.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_21.jpeg:Zone.Identifier
# Cleaan (107).jpeg
# images.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images.jpeg:Zone.Identifier
# images_12.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_12.jpeg:Zone.Identifier
# Cleaan (136).jpeg
# Cleaan (144).jpeg
# Cleaan (25).jpeg
# Cleaan (60).jpeg
# Cleaan (155).jpeg
# Cleaan (34).jpeg
# Cleaan (74).jpeg
# Cleaan (130).jpeg
# Cleaan (53).jpeg
# Cleaan (62).jpeg
# images_19.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_19.jpeg:Zone.Identifier
# Cleaan (20).jpeg
# Cleaan (23).jpeg
# Cleaan (159).jpeg
# Cleaan (200).jpeg
# Cleaan (45).jpeg
# Cleaan (124).jpeg
# Cleaan (108).jpeg
# Cleaan (138).jpeg
# Cleaan (29).jpeg
# Cleaan (118).jpeg
# Cleaan (26).jpeg
# images.jpeg
# Cleaan (101).jpeg
# Cleaan (167).jpeg
# Cleaan (96).jpeg
# Cleaan (106).jpeg
# images_11.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_11.jpeg:Zone.Identifier
# images_18.jpeg
# Cleaan (102).jpeg
# Cleaan (41).jpeg
# Cleaan (28).jpeg
# images_13.jpeg
# Cleaan (5).jpeg
# Cleaan (112).jpeg
# Cleaan (105).jpeg
# Cleaan (181).jpeg
# Cleaan (189).jpeg
# Cleaan (126).jpeg
# Cleaan (142).jpeg
# Cleaan (78).jpeg
# Cleaan (58).jpeg
# images_2.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_2.jpeg:Zone.Identifier
# Cleaan (116).jpeg
# Cleaan (94).jpeg
# Cleaan (175).jpeg
# images_7.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_7.jpeg:Zone.Identifier
# Cleaan (84).jpeg
# images_6.jpeg
# Cleaan (160).jpeg
# Cleaan (140).jpeg
# Cleaan (114).jpeg
# images_20.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_20.jpeg:Zone.Identifier
# Cleaan (121).jpeg
# Cleaan (38).jpeg
# Cleaan (43).jpeg
# Cleaan (85).jpeg
# images_2.jpeg
# Cleaan (122).jpeg
# Cleaan (73).jpeg
# Cleaan (47).jpeg
# Cleaan (187).jpeg
# Cleaan (176).jpeg
# Cleaan (75).jpeg
# Cleaan (39).jpeg
# Cleaan (147).jpeg
# images_20.jpeg
# Cleaan (117).jpeg
# Cleaan (3).jpeg
# Cleaan (82).jpeg
# Cleaan (92).jpeg
# images_13.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/clean/images_13.jpeg:Zone.Identifier
# Cleaan (173).jpeg
# Cleaan (132).jpeg
# Cleaan (15).jpeg
# Cleaan (149).jpeg
# Deletion of Zone.Identifier files complete.
# Bird (85).jpeg
# Bird (159).jpeg
# Dust (152).jpeg
# Dust (54).jpeg
# Bird (3).jpeg
# Bird (67).jpeg
# Dust (20).jpeg
# Dust (79).jpeg
# Dust (140).jpeg
# Dust (75).jpeg
# Bird (184).jpeg
# Bird (72).jpeg
# Bird (91).jpeg
# Dust (91).jpeg
# Bird (64).jpeg
# Dust (16).jpeg
# Dust (71).jpeg
# Dust (34).jpeg
# Dust (30).jpeg
# Bird (98).jpeg
# Dust (87).jpeg
# Bird (14).jpeg
# Bird (109).jpeg
# Dust (3).jpeg
# Dust (114).jpeg
# Bird (23).jpeg
# Bird (56).jpeg
# Bird (18).jpeg
# Bird (127).jpeg
# Dust (52).jpeg
# Dust (105).jpeg
# Dust (19).jpeg
# Dust (8).jpeg
# Dust (174).jpeg
# Bird (117).jpeg
# Dust (90).jpeg
# Dust (108).jpeg
# Dust (150).jpeg
# Dust (106).jpeg
# Bird (94).jpeg
# Dust (21).jpeg
# Bird (51).jpeg
# Bird (103).jpeg
# Dust (133).jpeg
# Dust (59).jpeg
# Dust (175).jpeg
# Dust (42).jpeg
# Bird (45).jpeg
# Bird (81).jpeg
# Bird (71).jpeg
# Bird (113).jpeg
# Dust (49).jpeg
# Dust (180).jpeg
# Dust (41).jpeg
# Bird (17).jpeg
# Dust (148).jpeg
# Dust (74).jpeg
# Dust (102).jpeg
# Bird (160).jpeg
# Dust (197).jpeg
# Dust (217).jpeg
# Dust (6).jpeg
# Dust (117).jpeg
# Bird (32).jpeg
# Dust (47).jpeg
# Dust (143).jpeg
# Bird (22).jpeg
# Dust (53).jpeg
# Dust (132).jpeg
# Dust (129).jpeg
# Dust (167).jpeg
# Bird (93).jpeg
# Dust (137).jpeg
# Bird (58).jpeg
# Dust (10).jpeg
# Dust (33).jpeg
# Bird (87).jpeg
# Bird (116).jpeg
# Bird (78).jpeg
# Bird (188).jpeg
# Dust (32).jpeg
# Dust (104).jpeg
# Bird (21).jpeg
# Dust (13).jpeg
# Dust (191).jpeg
# Dust (61).jpeg
# Dust (22).jpeg
# Dust (188).jpeg
# Bird (106).jpeg
# Bird (1).jpeg
# Dust (145).jpeg
# Bird (110).jpeg
# Dust (155).jpeg
# Bird (8).jpeg
# Bird (123).jpeg
# Bird (90).jpeg
# Dust (183).jpeg
# Bird (29).jpeg
# Dust (161).jpeg
# Dust (186).jpeg
# Dust (18).jpeg
# Bird (137).jpeg
# Dust (153).jpeg
# Bird (187).jpeg
# Dust (139).jpeg
# Dust (5).jpeg
# Dust (126).jpeg
# Dust (100).jpeg
# Bird (174).jpeg
# Bird (99).jpeg
# Dust (76).jpeg
# Dust (111).jpeg
# Dust (207).jpeg
# Bird (196).jpeg
# Dust (29).jpeg
# Dust (98).jpeg
# Dust (136).jpeg
# Bird (192).jpeg
# Dust (50).jpeg
# Bird (92).jpeg
# Dust (55).jpeg
# Dust (170).jpeg
# Bird (143).jpeg
# Dust (160).jpeg
# Bird (142).jpeg
# Bird (60).jpeg
# Dust (163).jpeg
# Dust (84).jpeg
# Dust (51).jpeg
# Dust (198).jpeg
# Bird (129).jpeg
# Dust (12).jpeg
# Dust (128).jpeg
# Bird (63).jpeg
# Dust (57).jpeg
# Dust (192).jpeg
# Bird (179).jpeg
# Bird (73).jpeg
# Dust (64).jpeg
# Dust (35).jpeg
# Bird (74).jpeg
# Bird (162).jpeg
# Dust (213).jpeg
# Dust (142).jpeg
# Dust (200).jpeg
# Dust (48).jpeg
# Bird (112).jpeg
# Dust (116).jpeg
# Bird (20).jpeg
# Bird (89).jpeg
# Dust (31).jpeg
# Dust (86).jpeg
# Dust (81).jpeg
# Bird (139).jpeg
# Dust (120).jpeg
# Dust (2).jpeg
# Dust (78).jpeg
# Bird (138).jpeg
# Bird (134).jpeg
# Bird (181).jpeg
# Bird (151).jpeg
# Bird (12).jpeg
# Bird (80).jpeg
# Dust (149).jpeg
# Bird (84).jpeg
# Dust (27).jpeg
# Dust (147).jpeg
# Bird (27).jpeg
# Bird (7).jpeg
# Bird (6).jpeg
# Bird (119).jpeg
# Dust (141).jpeg
# Dust (45).jpeg
# Dust (176).jpeg
# Dust (9).jpeg
# Dust (134).jpeg
# Dust (154).jpeg
# Dust (215).jpeg
# Bird (100).jpeg
# Dust (93).jpeg
# Bird (35).jpeg
# Dust (99).jpeg
# Bird (66).jpeg
# Dust (196).jpeg
# Dust (97).jpeg
# Bird (197).jpeg
# Dust (162).jpeg
# Dust (158).jpeg
# Bird (30).jpeg
# Bird (97).jpeg
# Dust (121).jpeg
# Bird (141).jpeg
# Dust (135).jpeg
# Bird (95).jpeg
# Bird (16).jpeg
# Bird (96).jpeg
# Bird (115).jpeg
# Dust (209).jpeg
# Dust (146).jpeg
# Bird (165).jpeg
# Bird (183).jpeg
# Dust (101).jpeg
# Bird (155).jpeg
# Dust (205).jpeg
# Bird (146).jpeg
# Dust (103).jpeg
# Bird (49).jpeg
# Bird (185).jpeg
# Bird (34).jpeg
# Dust (107).jpeg
# Bird (41).jpeg
# Dust (204).jpeg
# Bird (42).jpeg
# Dust (194).jpeg
# Dust (184).jpeg
# Bird (19).jpeg
# Dust (23).jpeg
# Bird (11).jpeg
# Dust (95).jpeg
# Bird (135).jpeg
# Bird (120).jpeg
# Dust (92).jpeg
# Dust (25).jpeg
# Bird (36).jpeg
# Dust (24).jpeg
# Dust (70).jpeg
# Dust (56).jpeg
# Dust (214).jpeg
# Dust (202).jpeg
# Dust (113).jpeg
# Dust (94).jpeg
# Bird (114).jpeg
# Bird (62).jpeg
# Bird (193).jpeg
# Dust (219).jpeg
# Dust (138).jpeg
# Dust (69).jpeg
# Bird (75).jpeg
# Bird (130).jpeg
# Bird (175).jpeg
# Dust (124).jpeg
# Bird (54).jpeg
# Bird (70).jpeg
# Bird (154).jpeg
# Dust (122).jpeg
# Bird (28).jpeg
# Dust (166).jpeg
# Bird (147).jpeg
# Bird (83).jpeg
# Dust (66).jpeg
# Dust (193).jpeg
# Bird (77).jpeg
# Dust (17).jpeg
# Bird (10).jpeg
# Dust (125).jpeg
# Bird (88).jpeg
# Dust (28).jpeg
# Dust (36).jpeg
# Bird (125).jpeg
# Bird (107).jpeg
# Dust (123).jpeg
# Dust (62).jpeg
# Dust (211).jpeg
# Dust (190).jpeg
# Dust (4).jpeg
# Bird (105).jpeg
# Bird (157).jpeg
# Dust (14).jpeg
# Dust (151).jpeg
# Bird (31).jpeg
# Bird (122).jpeg
# Bird (9).jpeg
# Bird (61).jpeg
# Bird (86).jpeg
# Dust (44).jpeg
# Bird (104).jpeg
# Dust (39).jpeg
# Dust (119).jpeg
# Bird (82).jpeg
# Bird (5).jpeg
# Dust (80).jpeg
# Dust (169).jpeg
# Bird (198).jpeg
# Dust (63).jpeg
# Bird (69).jpeg
# Dust (110).jpeg
# Bird (182).jpeg
# Bird (68).jpeg
# Dust (96).jpeg
# Dust (195).jpeg
# Dust (11).jpeg
# Bird (108).jpeg
# Dust (72).jpeg
# Bird (133).jpeg
# Bird (101).jpeg
# Bird (24).jpeg
# Dust (88).jpeg
# Dust (67).jpeg
# Dust (43).jpeg
# Dust (7).jpeg
# Dust (127).jpeg
# Dust (83).jpeg
# Bird (124).jpeg
# Bird (191).jpeg
# Bird (132).jpeg
# Dust (46).jpeg
# Dust (115).jpeg
# Dust (37).jpeg
# Dust (65).jpeg
# Dust (178).jpeg
# Dust (112).jpeg
# Dust (15).jpeg
# Dust (40).jpeg
# Dust (89).jpeg
# Dust (26).jpeg
# Dust (77).jpeg
# Bird (38).jpeg
# Bird (79).jpeg
# Bird (2).jpeg
# Bird (102).jpeg
# Dust (58).jpeg
# Dust (1).jpeg
# Bird (25).jpeg
# Dust (73).jpeg
# Bird (52).jpeg
# Dust (60).jpeg
# Bird (152).jpeg
# Dust (172).jpeg
# Bird (170).jpeg
# Bird (172).jpeg
# Bird (150).jpeg
# Bird (46).jpeg
# Dust (68).jpeg
# Bird (131).jpeg
# Bird (15).jpeg
# Dust (131).jpeg
# Dust (130).jpeg
# Bird (44).jpeg
# Dust (118).jpeg
# Bird (128).jpeg
# Dust (144).jpeg
# Bird (50).jpeg
# Bird (76).jpeg
# Dust (82).jpeg
# Bird (126).jpeg
# Dust (38).jpeg
# Dust (109).jpeg
# Bird (40).jpeg
# Bird (39).jpeg
# Bird (57).jpeg
# Dust (85).jpeg
# Dust (203).jpeg
# Bird (164).jpeg
# Bird (4).jpeg
# Bird (26).jpeg
# Bird (118).jpeg
# Deletion of Zone.Identifier files complete.
# Electrical (89).jpeg
# images_17.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_17.jpeg:Zone.Identifier
# Electrical (59).jpeg
# images_6.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_6.jpeg:Zone.Identifier
# Electrical (94).jpeg
# Electrical (64).jpeg
# Electrical (1).png
# Electrical (2).jpeg
# Electrical (18).jpeg
# Electrical (79).jpeg
# Physical-damaged (34).jpeg
# images_3.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_3.jpeg:Zone.Identifier
# Physical-damaged (21).jpeg
# Electrical (36).jpeg
# Electrical (24).jpeg
# images_5.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_5.jpeg:Zone.Identifier
# Physical-damaged (32).jpeg
# Electrical (37).jpeg
# Electrical (65).jpeg
# images_16.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_16.jpeg:Zone.Identifier
# Physical-damaged (11).jpeg
# Electrical (85).jpeg
# Electrical (28).jpeg
# Electrical (8).jpeg
# Electrical (49).jpeg
# images_10.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_10.jpeg:Zone.Identifier
# Physical-damaged (17).jpeg
# images_12.jpeg
# Electrical (29).jpeg
# images_9.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_9.jpeg:Zone.Identifier
# images_14.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_14.jpeg:Zone.Identifier
# Electrical (31).jpeg
# Physical-damaged (31).jpeg
# Electrical (44).jpeg
# Physical-damaged (35).jpeg
# Physical-damaged (25).jpeg
# Electrical (54).jpeg
# Electrical (3).png
# Electrical (2).png
# Electrical (55).jpeg
# Physical-damaged (19).jpeg
# Physical-damaged (29).jpeg
# Electrical (4).jpeg
# Electrical (39).jpeg
# Physical-damaged (26).jpeg
# images_21.jpeg
# image_1.jpeg
# Electrical (33).jpeg
# images_15.jpeg
# Electrical (53).jpeg
# Physical-damaged (18).jpeg
# Physical-damaged (22).jpeg
# Electrical (41).jpeg
# images_15.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_15.jpeg:Zone.Identifier
# Physical-damaged (7).jpeg
# Electrical (52).jpeg
# Electrical (50).jpeg
# Physical-damaged (66).jpeg
# Electrical (45).jpeg
# images_17.jpeg
# Physical-damaged (62).jpeg
# Electrical (67).jpeg
# Physical-damaged (39).jpeg
# Electrical (63).jpeg
# Electrical (74).jpeg
# Physical-damaged (36).jpeg
# Electrical (15).jpeg
# Electrical (34).jpeg
# Physical-damaged (41).jpeg
# Electrical (57).jpeg
# Electrical (21).jpeg
# images_19.jpeg
# images_7.jpeg
# Electrical (20).jpeg
# Electrical (26).jpeg
# Electrical (3).jpeg
# Physical-damaged (16).jpeg
# Physical-damaged (52).jpeg
# Electrical (88).jpeg
# Electrical (38).jpeg
# Physical-damaged (30).jpeg
# Electrical (95).jpeg
# Electrical (7).jpeg
# images_11.jpeg
# Electrical (46).jpeg
# Physical-damaged (27).jpeg
# Physical-damaged (3).jpeg
# Electrical (58).jpeg
# Electrical (60).jpeg
# Electrical (73).jpeg
# Physical-damaged (38).jpeg
# Physical-damaged (28).jpeg
# Electrical (10).jpeg
# images_5.jpeg
# Physical-damaged (10).jpeg
# Electrical (66).jpeg
# images_9.jpeg
# Electrical (19).jpeg
# Physical-damaged (53).jpeg
# Electrical (61).jpeg
# Electrical (35).jpeg
# images_4.jpeg
# Electrical (78).jpeg
# Physical-damaged (45).jpeg
# Electrical (5).jpeg
# Physical-damaged (56).jpeg
# Electrical (9).jpeg
# images_18.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_18.jpeg:Zone.Identifier
# Electrical (30).jpeg
# Physical-damaged (20).jpeg
# images_14.jpeg
# Physical-damaged (4).jpeg
# Electrical (27).jpeg
# Electrical (11).jpeg
# Electrical (1).jpeg
# Physical-damaged (61).jpeg
# Electrical (25).jpeg
# Physical-damaged (9).jpeg
# Electrical (13).jpeg
# Electrical (80).jpeg
# Physical-damaged (47).jpeg
# Physical-damaged (23).jpeg
# Physical-damaged (24).jpeg
# images_10.jpeg
# images_3.jpeg
# Physical-damaged (64).jpeg
# Physical-damaged (8).jpeg
# Physical-damaged (2).jpeg
# Physical-damaged (43).jpeg
# Electrical (23).jpeg
# images_16.jpeg
# images_21.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_21.jpeg:Zone.Identifier
# Physical-damaged (1).jpeg
# Electrical (51).jpeg
# images_12.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_12.jpeg:Zone.Identifier
# images_22.jpeg
# Physical-damaged (12).jpeg
# Electrical (17).jpeg
# Electrical (6).jpeg
# Physical-damaged (33).jpeg
# image_1.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/image_1.jpeg:Zone.Identifier
# Physical-damaged (14).jpeg
# Electrical (62).jpeg
# images_19.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_19.jpeg:Zone.Identifier
# Physical-damaged (37).jpeg
# Physical-damaged (15).jpeg
# Electrical (22).jpeg
# Electrical (68).jpeg
# Physical-damaged (5).jpeg
# images_4.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_4.jpeg:Zone.Identifier
# Electrical (14).jpeg
# Electrical (47).jpeg
# images_11.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_11.jpeg:Zone.Identifier
# images_18.jpeg
# images_13.jpeg
# image_8.jpeg
# image_8.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/image_8.jpeg:Zone.Identifier
# Physical-damaged (40).jpeg
# Electrical (42).jpeg
# images_2.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_2.jpeg:Zone.Identifier
# images_7.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_7.jpeg:Zone.Identifier
# Electrical (32).jpeg
# Physical-damaged (57).jpeg
# Electrical (56).jpeg
# images_6.jpeg
# Electrical (76).jpeg
# Physical-damaged (44).jpeg
# Electrical (43).jpeg
# Physical-damaged (60).jpeg
# images_20.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_20.jpeg:Zone.Identifier
# images_2.jpeg
# Electrical (90).jpeg
# Physical-damaged (13).jpeg
# Electrical (16).jpeg
# images_20.jpeg
# Electrical (86).jpeg
# Electrical (12).jpeg
# Electrical (48).jpeg
# Physical-damaged (54).jpeg
# images_13.jpeg:Zone.Identifier
# Deleted: raw_data/training-data-exp/damage/images_13.jpeg:Zone.Identifier
# images_23.jpeg
# Electrical (40).jpeg
# Physical-damaged (46).jpeg
# Physical-damaged (42).jpeg
# Physical-damaged (6).jpeg
# Deletion of Zone.Identifier files complete.

# %%
# Define the directory path
dirs = ['clean', 'dust','bird','electrical', 'physical_damaged','solar']
for dir in dirs:
    directory_path = f"raw_data/test-data/{dir}"

    # Iterate through the directory and delete Zone.Identifier files
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            print(file)
            if file.endswith("Zone.Identifier"):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted: {file_path}")

    print("Deletion of Zone.Identifier files complete.")

# %%
# Define the directory path
directory_path = "raw_data/training-data"

# List all files in the directory
file_list = []

for root, dirs, files in os.walk(directory_path):
    for file in files:
        file_path = os.path.join(root, file)
        file_list.append(file_path)

# Print the list of file paths
for file_path in file_list:
    print(file_path)
print(len(file_list))

# %% [markdown]
# ## Load images

# %%
batch_size = 16
train_data_dir = "raw_data/training-data-binary/"
#test_data_dir = "raw_data/test-data-binary/"

train_ds = image_dataset_from_directory(
  train_data_dir,
  labels = "inferred",
  label_mode = "binary",
  #class_names = ['clean','dust'],  
  seed=123,
  image_size=(225, 225),
  batch_size=batch_size,
  validation_split=0.2,
  subset='both'
) 

train_data = train_ds[0]
val_data = train_ds[1]

# We define a second one for the test data

# val_ds = image_dataset_from_directory(
#    test_data_dir,
#    labels = "inferred",
#    label_mode = "binary",
#    seed=123,
#    image_size=(225, 225),
#    batch_size=batch_size
#  )

# %%
class_names = train_data.class_names
print(class_names)

class_names = val_data.class_names
print(class_names)
len(train_ds)

# %% [markdown]
# ## Binary Model: clean vs dust

# %%
# We'll use a model with the same convolutional layers, but we'll add Augmentation layers before that

model_2 = Sequential()

model_2.add(layers.Rescaling(1./255, input_shape = (225, 225, 3)))

# Data Augmentation Layers

model_2.add(layers.RandomFlip("horizontal"))
model_2.add(layers.RandomZoom(0.1))
model_2.add(layers.RandomTranslation(0.2, 0.2))
model_2.add(layers.RandomRotation(0.1))


# Convolutional Layers

model_2.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_2.add(layers.Conv2D(filters = 32, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_2.add(layers.Conv2D(filters = 64, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_2.add(layers.Conv2D(filters = 128, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_2.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_2.add(layers.Flatten())

model_2.add(layers.Dense(64, activation="relu"))

model_2.add(layers.Dropout(0.5))

model_2.add(layers.Dense(1, activation="sigmoid"))

# %%
model_2.summary()

# %%
adam = optimizers.Adam(learning_rate = 0.001)

model_2.compile(loss= 'binary_crossentropy', #'categorical_crossentropy',
              optimizer= adam,
              metrics=['accuracy'])

# %%
MODEL = "model_2"

modelCheckpoint = callbacks.ModelCheckpoint("{}.h5".format(MODEL), monitor="val_loss", verbose=0, save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss", factor = 0.1, patience=3, verbose=1, min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)

# %%
# %%time

history_2 = model_2.fit(
        train_data,
        epochs=30,
        validation_data=val_data,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper]
        )

# %% [markdown]
# ### Plot history

# %%
def plot_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('accuracy')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()

# %%
plot_history(history_2)

# %% [markdown]
# ## Multi class Model

# %%
# We'll use a model with the same convolutional layers, but we'll add Augmentation layers before that

model_multi = Sequential()

model_multi.add(layers.Rescaling(1./255, input_shape = (225, 225, 3)))

# Data Augmentation Layers

model_multi.add(layers.RandomFlip("horizontal"))
model_multi.add(layers.RandomZoom(0.1))
model_multi.add(layers.RandomTranslation(0.2, 0.2))
model_multi.add(layers.RandomRotation(0.1))


# Convolutional Layers

model_multi.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model_multi.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_multi.add(layers.Conv2D(filters = 32, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_multi.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_multi.add(layers.Conv2D(filters = 64, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_multi.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_multi.add(layers.Conv2D(filters = 128, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_multi.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_multi.add(layers.Flatten())

model_multi.add(layers.Dense(64, activation="relu"))

model_multi.add(layers.Dropout(0.5))

model_multi.add(layers.Dense(6, activation="softmax"))

# %%
model_multi.summary()

# %%
adam = optimizers.Adam(learning_rate = 0.001)

model_multi.compile(loss= 'categorical_crossentropy',
              optimizer= adam,
              metrics=['accuracy'])

# %%
MODEL = "model_multi"

modelCheckpoint = callbacks.ModelCheckpoint("{}.h5".format(MODEL), monitor="val_loss", verbose=0, save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss", factor = 0.1, patience=3, verbose=1, min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)

# %%
#Data for multiclass model
batch_size = 16
train_data_dir = "raw_data/training-data/"
#test_data_dir = "raw_data/test-data-binary/"

train_ds = image_dataset_from_directory(
  train_data_dir,
  labels = "inferred",
  label_mode = "categorical",
  #class_names = ['clean','dust'],  
  seed=123,
  image_size=(225, 225),
  batch_size=batch_size,
  validation_split=0.2,
  subset='both'
) 

train_data = train_ds[0]
val_data = train_ds[1]

# %%
# %%time

history_multi = model_multi.fit(
        train_data,
        epochs=30,
        validation_data=val_data,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper]
        class_weight={},
        )

# %%
class_names = train_data.class_names
class_names

# %% [markdown]
# ### Helper functions

# %%
def find_index_of_max_element(input_list):
    max_value = max(input_list)
    max_index = input_list.index(max_value)
    return max_index

# %%
type(class_names)

# %%
def predictImage_multiclass(url, model):

  # Takes an image and a model

  img = url
  img = img_to_array(img)
  img = img.reshape((-1, 225, 225, 3))
  res = model.predict(img)
  print(f"Probabilities: ")
  names_of_classes = class_names
  print(f"{names_of_classes}")
  print(f"{res[0]}")
  print(f"Result: {names_of_classes[find_index_of_max_element(res[0].tolist())]}")  
  return res

# %%
def predictImage_binary(url, model):

  # Takes an imafe and a model

  img = url
  img = img_to_array(img)
  img = img.reshape((-1, 225, 225, 3))
  res = model.predict(img)
  print(f"Probabilities: ")
  print(f"{res[0]}")  
  res = model.predict(img)[0][0]
  if(res < 0.5):
    pred_class = "clean"
    prob = 1-res
  if(res >= 0.5):
    pred_class = "dust"
    prob = res

  print("Class : ", pred_class)
  print("probability = ",prob)

# %%
def predictImage_2(url, model):

  # Takes an imafe and a model

  img = url
  img = img_to_array(img)
  img = img.reshape((-1, 225, 225, 3))
  res = model.predict(img)[0][0]
  if(res < 0.5):
    animal = "cat"
    prob = 1-res
  if(res >= 0.5):
    animal = "dog"
    prob = res

  print("Animal : ", animal)
  print("probability = ",prob)

# %% [markdown]
# # Image investigation

# %% [markdown]
#  ### Class: Bird

# %%
img_bird = load_img(f"raw_data/training-data/bird/Bird (1).jpeg", target_size=(225, 225))
predictImage_multiclass(img_bird,model_multi)
plt.imshow(img_bird);

# %%
img_bird = load_img(f"raw_data/training-data/bird/Bird (5).jpeg", target_size=(225, 225))
predictImage_multiclass(img_bird,model_multi)
plt.imshow(img_bird);

# %%
img_bird = load_img(f"raw_data/training-data/bird/Bird (18).jpeg", target_size=(225, 225))
predictImage_multiclass(img_bird,model_multi)
plt.imshow(img_bird);

# %%
img_bird = load_img(f"raw_data/training-data/bird/Bird (22).jpeg", target_size=(225, 225))
predictImage_multiclass(img_bird,model_multi)
plt.imshow(img_bird);

# %%
img_bird = load_img(f"raw_data/training-data/bird/Bird (37).jpeg", target_size=(225, 225))
predictImage_multiclass(img_bird,model_multi)
plt.imshow(img_bird);

# %%
img_bird = load_img(f"raw_data/training-data/bird/Bird (39).jpeg", target_size=(225, 225))
predictImage_multiclass(img_bird,model_multi)
plt.imshow(img_bird);

# %% [markdown]
#  ### Class: clean

# %%
img_clean_1 = load_img(f"raw_data/training-data/clean/Cleaan (4).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_1,model_2)
plt.imshow(img_clean_1);

# %%
img_clean_2 = load_img(f"raw_data/training-data/clean/Cleaan (15).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_2,model_2)
plt.imshow(img_clean_2);

# %%
img_clean_3 = load_img(f"raw_data/training-data/clean/Cleaan (56).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_3,model_2)
plt.imshow(img_clean_3);

# %% [markdown]
# ### Class: physical-damage

# %%
img_physical = load_img(f"raw_data/training-data/physical_damaged/Physical-damaged (1).jpeg", target_size=(225, 225))
predictImage_multiclass(img_physical,model_multi)
plt.imshow(img_physical);

# %%
img_physical = load_img(f"raw_data/training-data/physical_damaged/Physical-damaged (20).jpeg", target_size=(225, 225))
predictImage_multiclass(img_physical,model_multi)
plt.imshow(img_physical);

# %%
img_physical = load_img(f"raw_data/training-data/physical_damaged/Physical-damaged (35).jpeg", target_size=(225, 225))
predictImage_multiclass(img_physical,model_multi)
plt.imshow(img_physical);

# %% [markdown]
# ### Class: electrical

# %%
img_electrical = load_img(f"raw_data/training-data/electrical/Electrical (28).jpeg", target_size=(225, 225))
predictImage_multiclass(img_electrical,model_multi)
plt.imshow(img_electrical);

# %%
img_electrical = load_img(f"raw_data/training-data/electrical/Electrical (29).jpeg", target_size=(225, 225))
predictImage_multiclass(img_electrical,model_multi)
plt.imshow(img_electrical);

# %% [markdown]
# ### Class: snow

# %%
img_snow = load_img(f"raw_data/training-data/solar/Solar (28).jpeg", target_size=(225, 225))
predictImage_multiclass(img_snow,model_multi)
plt.imshow(img_snow);

# %%
img_snow = load_img(f"raw_data/training-data/solar/Solar (3).jpeg", target_size=(225, 225))
predictImage_multiclass(img_snow,model_multi)
plt.imshow(img_snow);

# %%
img_snow = load_img(f"raw_data/training-data/solar/Solar (33).jpeg", target_size=(225, 225))
predictImage_multiclass(img_snow,model_multi)
plt.imshow(img_snow);

# %% [markdown]
# ### Class: dust

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (15).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_2,model_2)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (70).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_2,model_2)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (84).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_2,model_2)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (35).jpeg", target_size=(225, 225))
predictImage_binary(img_clean_2,model_2)
plt.imshow(img_clean_2);

# %% [markdown]
# ### Dust: multiclass

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (35).jpeg", target_size=(225, 225))
predictImage_multiclass(img_clean_2,model_multi)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (36).jpeg", target_size=(225, 225))
predictImage_multiclass(img_clean_2,model_multi)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (41).jpeg", target_size=(225, 225))
predictImage_multiclass(img_clean_2,model_multi)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (42).jpeg", target_size=(225, 225))
predictImage_multiclass(img_clean_2,model_multi)
plt.imshow(img_clean_2);

# %%
img_clean_2 = load_img(f"raw_data/training-data/dust/Dust (39).jpeg", target_size=(225, 225))
predictImage_multiclass(img_clean_2,model_multi)
plt.imshow(img_clean_2);

# %% [markdown]
# ## Binary model: Clean vs Snow

# %%
# We'll use a model with the same convolutional layers, but we'll add Augmentation layers before that

model_clean_snow = Sequential()

model_clean_snow.add(layers.Rescaling(1./255, input_shape = (225, 225, 3)))

# Data Augmentation Layers

model_clean_snow.add(layers.RandomFlip("horizontal"))
model_clean_snow.add(layers.RandomZoom(0.1))
model_clean_snow.add(layers.RandomTranslation(0.2, 0.2))
model_clean_snow.add(layers.RandomRotation(0.1))


# Convolutional Layers

model_clean_snow.add(layers.Conv2D(filters = 32, kernel_size = (3,3), activation="relu", padding = "same"))
model_clean_snow.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_clean_snow.add(layers.Conv2D(filters = 32, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_clean_snow.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )


model_clean_snow.add(layers.Conv2D(filters = 64, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_clean_snow.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_clean_snow.add(layers.Conv2D(filters = 128, kernel_size = (3,3), input_shape = (225, 225, 3), activation="relu", padding = "same"))
model_clean_snow.add(layers.MaxPooling2D(pool_size=(2, 2), padding = "same") )

model_clean_snow.add(layers.Flatten())

model_clean_snow.add(layers.Dense(64, activation="relu"))

model_clean_snow.add(layers.Dropout(0.5))

model_clean_snow.add(layers.Dense(1, activation="sigmoid"))
